# %%
#Uisng the wine_data given,
#1) Import pandas library
#2) Load your data, convert to a dataframe and assign it to it a variable name 
#3) Display the number of entries of your data.
#4) Display all taster names of 
# i)Display all taster names and their twitter handles of wines they tasted that were produced in:
#               i) Portugal  ii) France
#Find all missing values in the prices and points columns and fill them with estimatedvalues.
#Derive insights from questions 4&5

# %%
#question 2
import pandas as pd
wine_tasting_data=pd.read_csv('/Users/yaa.adobea/Downloads/wine_data.csv')
wine_tasting_data
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
#no of shapes
wine_tasting_data.shape
# Out:
# (129971, 14)

# %%
wine_tasting_data['taster_name']
# Out:
# 0              Kerin O’Keefe
# 1                 Roger Voss
# 2               Paul Gregutt
# 3         Alexander Peartree
# 4               Paul Gregutt
#                  ...
# 129966    Anna Lee C. Iijima
# 129967          Paul Gregutt
# 129968            Roger Voss
# 129969            Roger Voss
# 129970            Roger Voss
# Name: taster_name, Length: 129971, dtype: object

# %%
# taster names and their twitter handle in portugal
wine_tasting_data_1=wine_tasting_data[['country','taster_name','taster_twitter_handle']]
wine_tasting_data_1.loc[wine_tasting_data_1.country=='Portugal']
# Out:
#          country taster_name taster_twitter_handle
# 1       Portugal  Roger Voss            @vossroger
# 79      Portugal  Roger Voss            @vossroger
# 151     Portugal  Roger Voss            @vossroger
# 157     Portugal  Roger Voss            @vossroger
# 203     Portugal  Roger Voss            @vossroger
# ...          ...         ...                   ...
# 129863  Portugal  Roger Voss            @vossroger
# 129864  Portugal  Roger Voss            @vossroger
# 129865  Portugal  Roger Voss            @vossroger
# 129901  Portugal  Roger Voss            @vossroger
# 129960  Portugal  Roger Voss            @vossroger
#
# [5691 rows x 3 columns]

# %%
#taster name and their twitter handle in france
wine_tasting_data_1.loc[wine_tasting_data_1.country=='France']
# Out:
#        country taster_name taster_twitter_handle
# 7       France  Roger Voss            @vossroger
# 9       France  Roger Voss            @vossroger
# 11      France  Roger Voss            @vossroger
# 30      France  Roger Voss            @vossroger
# 42      France  Roger Voss            @vossroger
# ...        ...         ...                   ...
# 129964  France  Roger Voss            @vossroger
# 129965  France  Roger Voss            @vossroger
# 129968  France  Roger Voss            @vossroger
# 129969  France  Roger Voss            @vossroger
# 129970  France  Roger Voss            @vossroger
#
# [22093 rows x 3 columns]

# %%
wine_tasting_data.loc[wine_tasting_data.price.isnull()]
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 13              13     Italy
# 30              30    France
# 31              31     Italy
# 32              32     Italy
# ...            ...       ...
# 129844      129844     Italy
# 129860      129860  Portugal
# 129863      129863  Portugal
# 129893      129893     Italy
# 129964      129964    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 13      This is dominated by oak and oak-driven aromas...
# 30      Red cherry fruit comes laced with light tannin...
# 31      Merlot and Nero d'Avola form the base for this...
# 32      Part of the extended Calanìca series, this Gri...
# ...                                                   ...
# 129844  Doga delle Clavule is a neutral, mineral-drive...
# 129860  This rich wine has a firm structure as well as...
# 129863  This mature wine that has 50% Touriga Nacional...
# ...

# %%
wine_tasting_data.loc[wine_tasting_data.price.isnull()].fillna(70)
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 13              13     Italy
# 30              30    France
# 31              31     Italy
# 32              32     Italy
# ...            ...       ...
# 129844      129844     Italy
# 129860      129860  Portugal
# 129863      129863  Portugal
# 129893      129893     Italy
# 129964      129964    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 13      This is dominated by oak and oak-driven aromas...
# 30      Red cherry fruit comes laced with light tannin...
# 31      Merlot and Nero d'Avola form the base for this...
# 32      Part of the extended Calanìca series, this Gri...
# ...                                                   ...
# 129844  Doga delle Clavule is a neutral, mineral-drive...
# 129860  This rich wine has a firm structure as well as...
# 129863  This mature wine that has 50% Touriga Nacional...
# ...

# %%
wine_tasting_data.loc[wine_tasting_data.points.isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, country, description, designation, points, price, province, region_1, region_2, taster_name, taster_twitter_handle, title, variety, winery]
# Index: []

# %%
#estimate a value for price
wine_tasting_data.describe(include='all')
# Out:
#            Unnamed: 0 country  \
# count   129971.000000  129908
# unique            NaN      43
# top               NaN      US
# freq              NaN   54504
# mean     64985.000000     NaN
# std      37519.540256     NaN
# min          0.000000     NaN
# 25%      32492.500000     NaN
# 50%      64985.000000     NaN
# 75%      97477.500000     NaN
# max     129970.000000     NaN
#
#                                               description designation  \
# count                                              129971       92506
# unique                                             119955       37979
# top     Seductively tart in lemon pith, cranberry and ...     Reserve
# freq                                                    3        2009
# mean                                                  NaN         NaN
# std                                                   NaN         NaN
# min                                                   NaN         NaN
# ...

# %%
#now the mean is 35
wine_tasting_data.price.fillna(35,inplace=True)

# %%
wine_tasting_data
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...
